# %%
import pandas as pd

# Lade die CSV-Datei als DataFrame
df_loaded = pd.read_csv("ParetoFront.csv")

# Zeige die ersten Zeilen an
display(df_loaded)  # Falls du in Jupyter Notebook bist
# Out:
#      Finished Orders  Dynamic Percentage  Order Items  Driver Violation  \
# 0                 29                29.0          297                47
# 1                 29                29.0          297                48
# 2                 29                29.0          297                48
# 3                 29                29.0          297                48
# 4                 29                29.0          297                48
# ..               ...                 ...          ...               ...
# 645               29                29.0          297               277
# 646               29                29.0          297               277
# 647               29                29.0          297               278
# 648               29                29.0          297               278
# 649               29                29.0          297               278
#
#      Commute Distance  Transport Machines  Transport Attachments  Machines  \
# ...

# %%
from tabulate import tabulate

print(tabulate(df_loaded, headers="keys", tablefmt="fancy_grid"))
# Out:
# ╒═════╤═══════════════════╤══════════════════════╤═══════════════╤════════════════════╤════════════════════╤══════════════════════╤═════════════════════════╤════════════╤═══════════╤═══════════════╕
# │     │   Finished Orders │   Dynamic Percentage │   Order Items │   Driver Violation │   Commute Distance │   Transport Machines │   Transport Attachments │   Machines │   Workers │   Attachments │
# ╞═════╪═══════════════════╪══════════════════════╪═══════════════╪════════════════════╪════════════════════╪══════════════════════╪═════════════════════════╪════════════╪═══════════╪═══════════════╡
# │   0 │                29 │                   29 │           297 │                 47 │            32591.9 │             10629.8  │                       0 │         17 │        33 │            12 │
# ...

# %%
import qgrid
from IPython.display import display

# Interaktive Tabelle erstellen
qgrid_widget = qgrid.show_grid(df_loaded, show_toolbar=True)

# Anzeigen im Jupyter Notebook
display(qgrid_widget)
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…
