# %%
# Zelle 1: Imports
import json

# Zelle 2: Initialisierung der Ergebnislisten
auftraege_counts = []
bestellpositionen_counts = []

# Zelle 3: Alle Monate durchgehen und zählen
for month in range(7, 11):
    for part in range(1, 5):
        filename = f"Construction_RealLife_2024_{month}_{part}_4.json"
        try:
            with open(filename, "r", encoding="utf-8") as f:
                data = json.load(f)

            auftraege = data.get("Auftraege", [])
            bestellpositionen = data.get("Bestellpositionen", [])
            workers = data.get("Arbeiter", [])
            machines = data.get("Maschinen", [])
            attachments = data.get("Anbaugeraete", [])

            num_auftraege = len(auftraege)
            num_bestellpositionen = len(bestellpositionen)
            num_workers = len(workers)
            num_machines = len(machines)
            num_attachments = len(attachments)


            auftraege_counts.append(num_auftraege)
            bestellpositionen_counts.append(num_bestellpositionen)

            print(f"Monat {month}_{part}_4:")
            print(f"  Anzahl der Aufträge: {num_auftraege}")
            print(f"  Anzahl der Bestellpositionen: {num_bestellpositionen}")
            print(f"  Anzahl der Maschinen: {num_machines}")
            print(f"  Anzahl der Arbeiter: {num_workers}")
            print(f"  Anzahl der Anbaugeräte: {num_attachments}")
            print("-" * 40)

        except FileNotFoundError:
            print(f"Datei {filename} nicht gefunden.")
        except json.JSONDecodeError:
            print(f"Datei {filename} konnte nicht als JSON geladen werden.")

# Zelle 4: Min/Max-Werte ausgeben
if auftraege_counts and bestellpositionen_counts:
    print("Gesamtübersicht:")
    print(f"  Aufträge: min = {min(auftraege_counts)}, max = {max(auftraege_counts)}")
    print(f"  Bestellpositionen: min = {min(bestellpositionen_counts)}, max = {max(bestellpositionen_counts)}")
# Out:
# Monat 7_1_4:
#   Anzahl der Aufträge: 82
#   Anzahl der Bestellpositionen: 466
#   Anzahl der Maschinen: 65
#   Anzahl der Arbeiter: 118
#   Anzahl der Anbaugeräte: 391
# ----------------------------------------
# Monat 7_2_4:
#   Anzahl der Aufträge: 81
#   Anzahl der Bestellpositionen: 460
#   Anzahl der Maschinen: 65
#   Anzahl der Arbeiter: 118
#   Anzahl der Anbaugeräte: 391
# ----------------------------------------
# Monat 7_3_4:
#   Anzahl der Aufträge: 133
#   Anzahl der Bestellpositionen: 875
#   Anzahl der Maschinen: 65
#   Anzahl der Arbeiter: 118
#   Anzahl der Anbaugeräte: 391
# ----------------------------------------
# Monat 7_4_4:
#   Anzahl der Aufträge: 148
#   Anzahl der Bestellpositionen: 1237
#   Anzahl der Maschinen: 65
#   Anzahl der Arbeiter: 118
#   Anzahl der Anbaugeräte: 391
# ----------------------------------------
# Monat 8_1_4:
#   Anzahl der Aufträge: 142
#   Anzahl der Bestellpositionen: 888
#   Anzahl der Maschinen: 65
#   Anzahl der Arbeiter: 118
#   Anzahl der Anbaugeräte: 368
# ----------------------------------------
# Monat 8_2_4:
#   Anzahl der Aufträge: 123
#   Anzahl der Bestellpositionen: 829
#   Anzahl der Maschinen: 65
#   Anzahl der Arbeiter: 118
#   Anzahl der Anbaugeräte: 368
# ----------------------------------------
# Monat 8_3_4:
#   Anzahl der Aufträge: 126
#   Anzahl der Bestellpositionen: 894
#   Anzahl der Maschinen: 65
#   Anzahl der Arbeiter: 118
#   Anzahl der Anbaugeräte: 368
# ----------------------------------------
# Monat 8_4_4:
#   Anzahl der Aufträge: 118
#   Anzahl der Bestellpositionen: 1166
#   Anzahl der Maschinen: 65
#   Anzahl der Arbeiter: 118
#   Anzahl der Anbaugeräte: 368
# ----------------------------------------
# Monat 9_1_4:
#   Anzahl der Aufträge: 121
#   Anzahl der Bestellpositionen: 828
#   Anzahl der Maschinen: 65
#   Anzahl der Arbeiter: 118
#   Anzahl der Anbaugeräte: 377
# ----------------------------------------
# Monat 9_2_4:
#   Anzahl der Aufträge: 120
#   Anzahl der Bestellpositionen: 891
#   Anzahl der Maschinen: 65
#   Anzahl der Arbeiter: 118
#   Anzahl der Anbaugeräte: 377
# ----------------------------------------
# Monat 9_3_4:
#   Anzahl der Aufträge: 113
#   Anzahl der Bestellpositionen: 785
#   Anzahl der Maschinen: 65
#   Anzahl der Arbeiter: 118
#   Anzahl der Anbaugeräte: 377
# ----------------------------------------
# Monat 9_4_4:
#   Anzahl der Aufträge: 113
#   Anzahl der Bestellpositionen: 1019
#   Anzahl der Maschinen: 65
#   Anzahl der Arbeiter: 118
#   Anzahl der Anbaugeräte: 377
# ----------------------------------------
# Monat 10_1_4:
#   Anzahl der Aufträge: 107
#   Anzahl der Bestellpositionen: 764
#   Anzahl der Maschinen: 65
#   Anzahl der Arbeiter: 118
#   Anzahl der Anbaugeräte: 320
# ----------------------------------------
# Monat 10_2_4:
#   Anzahl der Aufträge: 112
#   Anzahl der Bestellpositionen: 834
#   Anzahl der Maschinen: 65
#   Anzahl der Arbeiter: 118
#   Anzahl der Anbaugeräte: 320
# ----------------------------------------
# Monat 10_3_4:
#   Anzahl der Aufträge: 110
#   Anzahl der Bestellpositionen: 760
#   Anzahl der Maschinen: 65
#   Anzahl der Arbeiter: 118
#   Anzahl der Anbaugeräte: 320
# ----------------------------------------
# Monat 10_4_4:
#   Anzahl der Aufträge: 104
#   Anzahl der Bestellpositionen: 1097
#   Anzahl der Maschinen: 65
#   Anzahl der Arbeiter: 118
#   Anzahl der Anbaugeräte: 320
# ----------------------------------------
# Gesamtübersicht:
#   Aufträge: min = 81, max = 148
#   Bestellpositionen: min = 460, max = 1237

# %%
import json

# Lade die JSON-Datei
with open("Construction_RealLife_2024_10_1.json", "r") as f:
    data = json.load(f)

# Extrahiere alle Baustellenstandorte
baustellen_standorte = [
    (item["Standort"]["Item1"], item["Standort"]["Item2"])
    for item in data["Auftraege"]
]

# Extrahiere alle Wohnorte der Arbeiter
arbeiter_wohnorte = [
    (worker["Wohnort"]["Item1"], worker["Wohnort"]["Item2"])
    for worker in data["Arbeiter"]
]

import folium

# Mittelpunkt berechnen (z. B. Mittelwert aller Koordinaten)
all_coords = baustellen_standorte + arbeiter_wohnorte
avg_lat = sum(lat for lat, _ in all_coords) / len(all_coords)
avg_lon = sum(lon for _, lon in all_coords) / len(all_coords)

# Erstelle die Karte zentriert auf den Mittelwert
karte = folium.Map(location=[avg_lat, avg_lon], zoom_start=8)

# Füge Baustellen als blaue Marker hinzu
for lat, lon in baustellen_standorte:
    folium.Marker(
        location=[lat, lon],
        popup="Baustelle",
        icon=folium.Icon(color="blue", icon="wrench", prefix="fa")
    ).add_to(karte)

# Füge Arbeiter als grüne Marker hinzu
for lat, lon in arbeiter_wohnorte:
    folium.Marker(
        location=[lat, lon],
        popup="Arbeiter",
        icon=folium.Icon(color="green", icon="user", prefix="fa")
    ).add_to(karte)

# Karte anzeigen
karte
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1072c9c0172369f457dc1a598de141a0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1072c9c0172369f457dc1a598de141a0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1072c9c0172369f457dc1a598de141a0 = L.map(
#                 &quot;map_1072c9c0172369f457dc1a598de141a0&quot;,
#                 {
#                     center: [49.698195001554694, 9.33724287740354],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6e5e1734a68e7706cc35838c4c1541df = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6e5e1734a68e7706cc35838c4c1541df.addTo(map_1072c9c0172369f457dc1a598de141a0);
#
#
#             var marker_f2dfee39358fe8d064e0a8bdbf4535b5 = L.marker(
#                 [49.9145711, 8.466917036913948],
#                 {
# }
#             ).addTo(map_1072c9c0172369f457dc1a598de141a0);
#
#
#             var icon_961784c692a57c78f7f9649e53a14f51 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;wrench&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_8801fcce663183779bf47b873356c07f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f09a56667df20ae70ec5f52be89e0a10 = $(`&lt;div id=&quot;html_f09a56667df20ae70ec5f52be89e0a10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Baustelle&lt;/div&gt;`)[0];
#                 popup_8801fcce663183779bf47b873356c07f.setContent(html_f09a56667df20ae70ec5f52be89e0a10);
#
#
#
#         marker_f2dfee39358fe8d064e0a8bdbf4535b5.bindPopup(popup_8801fcce663183779bf47b873356c07f)
#         ;
#
#
#
#
#                 marker_f2dfee39358fe8d064e0a8bdbf4535b5.setIcon(icon_961784c692a57c78f7f9649e53a14f51);
#
#
#             var marker_14694258e651cdcc1659e87d32bfaa5e = L.marker(
#                 [49.68867295, 8.431422651846013],
#                 {
# }
#             ).addTo(map_1072c9c0172369f457dc1a598de141a0);
#
#
#             var icon_ff58f5960354b735023f7607b5c58daf = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;wrench&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c88eabec6d0eb51aaaa6cbca19a12e1a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c6c51e5d76398e113d30930a42ade8e = $(`&lt;div id=&quot;html_9c6c51e5d76398e113d30930a42ade8e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Baustelle&lt;/div&gt;`)[0];
#                 popup_c88eabec6d0eb51aaaa6cbca19a12e1a.setContent(html_9c6c51e5d76398e113d30930a42ade8e);
#
#
#
#         marker_14694258e651cdcc1659e87d32bfaa5e.bindPopup(popup_c88eabec6d0eb51aaaa6cbca19a12e1a)
#         ;
#
#
#
#
#                 marker_14694258e651cdcc1659e87d32bfaa5e.setIcon(icon_ff58f5960354b735023f7607b5c58daf);
#
#
#             var marker_26785b0e05e20887d517dc951e135078 = L.marker(
#                 [49.98489525, 8.564881763700717],
#                 {
# }
#             ).addTo(map_1072c9c0172369f457dc1a598de141a0);
#
#
#             var icon_d75cc9479c72ff2acab3894caeae4684 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;wrench&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_2116b0001305634b366c0ce992a198e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b23ba7534e2ab748abe8dc67bf077a06 = $(`&lt;div id=&quot;html_b23ba7534e2ab748abe8dc67bf077a06&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Baustelle&lt;/div&gt;`)[0];
#                 popup_2116b0001305634b366c0ce992a198e9.setContent(html_b23ba7534e2ab748abe8dc67bf077a06);
#
#
#
#         marker_26785b0e05e20887d517dc951e135078.bindPopup(popup_2116b0001305634b366c0ce992a198e9)
#         ;
#
#
#
#
#                 marker_26785b0e05e20887d517dc951e135078.setIcon(icon_d75cc9479c72ff2acab3894caeae4684);
#
#
#             var marker_8ceaf6c756228d12824a0afe2339d643 = L.marker(
#                 [49.83363705, 8.503512650257882],
#                 {
# }
#             ).addTo(map_1072c9c0172369f457dc1a598de141a0);
#
#
#             var icon_fd890cdb4116a2a35f4d42f782b46a96 = L.AwesomeM
