# %%
# Zelle 1: Imports
import json

# Zelle 2: Initialisierung der Ergebnislisten
auftraege_counts = []
bestellpositionen_counts = []

# Zelle 3: Alle Monate durchgehen und zählen
for month in range(7, 11):
    filename = f"RealLife_2024_{month}.json"
    try:
        with open(filename, "r", encoding="utf-8") as f:
            data = json.load(f)

        auftraege = data.get("Auftraege", [])
        bestellpositionen = data.get("Bestellpositionen", [])
        workers = data.get("Arbeiter", [])
        machines = data.get("Maschinen", [])
        attachments = data.get("Anbaugeraete", [])

        num_auftraege = len(auftraege)
        num_bestellpositionen = len(bestellpositionen)
        num_workers = len(workers)
        num_machines = len(machines)
        num_attachments = len(attachments)


        auftraege_counts.append(num_auftraege)
        bestellpositionen_counts.append(num_bestellpositionen)

        print(f"Monat {month}:")
        print(f"  Anzahl der Aufträge: {num_auftraege}")
        print(f"  Anzahl der Bestellpositionen: {num_bestellpositionen}")
        print(f"  Anzahl der Maschinen: {num_machines}")
        print(f"  Anzahl der Arbeiter: {num_workers}")
        print(f"  Anzahl der Anbaugeräte: {num_attachments}")
        print("-" * 40)

    except FileNotFoundError:
        print(f"Datei {filename} nicht gefunden.")
    except json.JSONDecodeError:
        print(f"Datei {filename} konnte nicht als JSON geladen werden.")

# Zelle 4: Min/Max-Werte ausgeben
if auftraege_counts and bestellpositionen_counts:
    print("Gesamtübersicht:")
    print(f"  Aufträge: min = {min(auftraege_counts)}, max = {max(auftraege_counts)}")
    print(f"  Bestellpositionen: min = {min(bestellpositionen_counts)}, max = {max(bestellpositionen_counts)}")
# Out:
# Monat 7:
#   Anzahl der Aufträge: 175
#   Anzahl der Bestellpositionen: 3038
#   Anzahl der Maschinen: 65
#   Anzahl der Arbeiter: 118
#   Anzahl der Anbaugeräte: 391
# ----------------------------------------
# Monat 8:
#   Anzahl der Aufträge: 156
#   Anzahl der Bestellpositionen: 3777
#   Anzahl der Maschinen: 65
#   Anzahl der Arbeiter: 118
#   Anzahl der Anbaugeräte: 368
# ----------------------------------------
# Monat 9:
#   Anzahl der Aufträge: 125
#   Anzahl der Bestellpositionen: 3523
#   Anzahl der Maschinen: 65
#   Anzahl der Arbeiter: 118
#   Anzahl der Anbaugeräte: 377
# ----------------------------------------
# Monat 10:
#   Anzahl der Aufträge: 114
#   Anzahl der Bestellpositionen: 3455
#   Anzahl der Maschinen: 65
#   Anzahl der Arbeiter: 118
#   Anzahl der Anbaugeräte: 320
# ----------------------------------------
# Gesamtübersicht:
#   Aufträge: min = 114, max = 175
#   Bestellpositionen: min = 3038, max = 3777

# %%
import json

# Lade die JSON-Datei
with open("RealLife_2024_10.json", "r") as f:
    data = json.load(f)

# Extrahiere alle Baustellenstandorte
baustellen_standorte = [
    (item["Standort"]["Item1"], item["Standort"]["Item2"])
    for item in data["Auftraege"]
]

# Extrahiere alle Wohnorte der Arbeiter
arbeiter_wohnorte = [
    (worker["Wohnort"]["Item1"], worker["Wohnort"]["Item2"])
    for worker in data["Arbeiter"]
]

import folium

# Mittelpunkt berechnen (z. B. Mittelwert aller Koordinaten)
all_coords = baustellen_standorte + arbeiter_wohnorte
avg_lat = sum(lat for lat, _ in all_coords) / len(all_coords)
avg_lon = sum(lon for _, lon in all_coords) / len(all_coords)

# Erstelle die Karte zentriert auf den Mittelwert
karte = folium.Map(location=[avg_lat, avg_lon], zoom_start=8)

# Füge Baustellen als blaue Marker hinzu
for lat, lon in baustellen_standorte:
    folium.Marker(
        location=[lat, lon],
        popup="Baustelle",
        icon=folium.Icon(color="blue", icon="wrench", prefix="fa")
    ).add_to(karte)

# Füge Arbeiter als grüne Marker hinzu
for lat, lon in arbeiter_wohnorte:
    folium.Marker(
        location=[lat, lon],
        popup="Arbeiter",
        icon=folium.Icon(color="green", icon="user", prefix="fa")
    ).add_to(karte)

# Karte anzeigen
karte
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_42bd4f922f5f26c243fd423151d13243 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_42bd4f922f5f26c243fd423151d13243&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_42bd4f922f5f26c243fd423151d13243 = L.map(
#                 &quot;map_42bd4f922f5f26c243fd423151d13243&quot;,
#                 {
#                     center: [49.696647916600696, 9.340814820782814],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_967712f96ff107486f4206da40d2eb1a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_967712f96ff107486f4206da40d2eb1a.addTo(map_42bd4f922f5f26c243fd423151d13243);
#
#
#             var marker_55e54e9c96767313a95d2d25f4bcfdae = L.marker(
#                 [49.9145711, 8.466917036913948],
#                 {
# }
#             ).addTo(map_42bd4f922f5f26c243fd423151d13243);
#
#
#             var icon_a4d88948047c9c393250cd460d7504cc = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;wrench&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_bb67564e933dce6993312409d4104aae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b024e7816600e7a1466340aabc14ea21 = $(`&lt;div id=&quot;html_b024e7816600e7a1466340aabc14ea21&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Baustelle&lt;/div&gt;`)[0];
#                 popup_bb67564e933dce6993312409d4104aae.setContent(html_b024e7816600e7a1466340aabc14ea21);
#
#
#
#         marker_55e54e9c96767313a95d2d25f4bcfdae.bindPopup(popup_bb67564e933dce6993312409d4104aae)
#         ;
#
#
#
#
#                 marker_55e54e9c96767313a95d2d25f4bcfdae.setIcon(icon_a4d88948047c9c393250cd460d7504cc);
#
#
#             var marker_5feba3e20f9070528e7d821bbc43efe9 = L.marker(
#                 [49.68867295, 8.431422651846013],
#                 {
# }
#             ).addTo(map_42bd4f922f5f26c243fd423151d13243);
#
#
#             var icon_b69414834539fc378cc444156c181521 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;wrench&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_e64773f712ed585897c852132e94c829 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_719026b8114366e8b0310aee3c04cdf8 = $(`&lt;div id=&quot;html_719026b8114366e8b0310aee3c04cdf8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Baustelle&lt;/div&gt;`)[0];
#                 popup_e64773f712ed585897c852132e94c829.setContent(html_719026b8114366e8b0310aee3c04cdf8);
#
#
#
#         marker_5feba3e20f9070528e7d821bbc43efe9.bindPopup(popup_e64773f712ed585897c852132e94c829)
#         ;
#
#
#
#
#                 marker_5feba3e20f9070528e7d821bbc43efe9.setIcon(icon_b69414834539fc378cc444156c181521);
#
#
#             var marker_89a55318b693e198e0ec271e854be43f = L.marker(
#                 [49.98489525, 8.564881763700717],
#                 {
# }
#             ).addTo(map_42bd4f922f5f26c243fd423151d13243);
#
#
#             var icon_b9b6af981b4784f1d8c36137460e8ff1 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;wrench&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_87255318df568b81542526677997fbe4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_92de706f8852aa6fd7089702eebe588d = $(`&lt;div id=&quot;html_92de706f8852aa6fd7089702eebe588d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Baustelle&lt;/div&gt;`)[0];
#                 popup_87255318df568b81542526677997fbe4.setContent(html_92de706f8852aa6fd7089702eebe588d);
#
#
#
#         marker_89a55318b693e198e0ec271e854be43f.bindPopup(popup_87255318df568b81542526677997fbe4)
#         ;
#
#
#
#
#                 marker_89a55318b693e198e0ec271e854be43f.setIcon(icon_b9b6af981b4784f1d8c36137460e8ff1);
#
#
#             var marker_b955ca5c956a9849ea7ae17fdace1001 = L.marker(
#                 [49.83363705, 8.503512650257882],
#                 {
# }
#             ).addTo(map_42bd4f922f5f26c243fd423151d13243);
#
#
#             var icon_698689aa8f6037e804777c5129b9a6a2 = L.Awesome
